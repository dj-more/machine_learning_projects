# %%
params = {'n_estimators': [100,200,300,400,500], 'max_depth': [3,4,5], 'min_samples_split': [2,3,4],
          'learning_rate': [0.01,0.02,0.03], 'loss': 'ls'}

# %%
i=1
for estimator in params['n_estimators']:
    for depth in params['max_depth']:
        for split in params['min_samples_split']:
            for lr in params['learning_rate']:
                print(i,estimator,depth,split,lr)
                i=i+1
# Out:
# 1 100 3 2 0.01
# 2 100 3 2 0.02
# 3 100 3 2 0.03
# 4 100 3 3 0.01
# 5 100 3 3 0.02
# 6 100 3 3 0.03
# 7 100 3 4 0.01
# 8 100 3 4 0.02
# 9 100 3 4 0.03
# 10 100 4 2 0.01
# 11 100 4 2 0.02
# 12 100 4 2 0.03
# 13 100 4 3 0.01
# 14 100 4 3 0.02
# 15 100 4 3 0.03
# 16 100 4 4 0.01
# 17 100 4 4 0.02
# 18 100 4 4 0.03
# 19 100 5 2 0.01
# 20 100 5 2 0.02
# 21 100 5 2 0.03
# 22 100 5 3 0.01
# 23 100 5 3 0.02
# 24 100 5 3 0.03
# 25 100 5 4 0.01
# 26 100 5 4 0.02
# 27 100 5 4 0.03
# 28 200 3 2 0.01
# 29 200 3 2 0.02
# 30 200 3 2 0.03
# 31 200 3 3 0.01
# 32 200 3 3 0.02
# 33 200 3 3 0.03
# 34 200 3 4 0.01
# 35 200 3 4 0.02
# 36 200 3 4 0.03
# 37 200 4 2 0.01
# 38 200 4 2 0.02
# 39 200 4 2 0.03
# 40 200 4 3 0.01
# 41 200 4 3 0.02
# 42 200 4 3 0.03
# 43 200 4 4 0.01
# 44 200 4 4 0.02
# 45 200 4 4 0.03
# 46 200 5 2 0.01
# 47 200 5 2 0.02
# 48 200 5 2 0.03
# 49 200 5 3 0.01
# 50 200 5 3 0.02
# 51 200 5 3 0.03
# 52 200 5 4 0.01
# 53 200 5 4 0.02
# 54 200 5 4 0.03
# 55 300 3 2 0.01
# 56 300 3 2 0.02
# ...
